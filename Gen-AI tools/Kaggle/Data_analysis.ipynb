# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreevidhya08/Generative-AI/blob/main/Kaggle/DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("Disease_symptom_and_patient_profile_dataset.csv")

# %%
#Display first few rows of the dataset
df.head()

# %%
#Get information about the dataset
df.info()

# %%
#Get the number of rows and columns of the dataset
df.shape

# %%
#Check if any duplicate values are present in the data
df.columns.value_counts()

# %%
#Check whether there are any missing values in the data
df.isnull().sum()

# %%
#Disease-wise Outcome Analysis
pd.crosstab(df["Disease"], df["Outcome Variable"])

# %%
df.groupby(["Disease", "Fever"])["Outcome Variable"].value_counts()

# %%
#Visualize total number of Positive and Negative cases
import matplotlib.pyplot as plt

df["Outcome Variable"].value_counts().plot(kind="bar")
plt.xlabel("Outcome")
plt.ylabel("Count")
plt.title("Outcome Distribution")
plt.show()

# %%
(df[symptoms]
 .replace({"Yes": 1, "No": 0})
 .mean()
 .plot(kind="bar"))

plt.title("Overall Symptom Presence")
plt.ylabel("Proportion")
plt.show()
